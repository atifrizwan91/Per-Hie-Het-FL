# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
import time
import math
# from tensorflow import keras
from sklearn.metrics import mean_absolute_error, mean_squared_error, accuracy_score, r2_score
from keras.models import Sequential
from keras.layers import Dense, Dropout,Input
from pathlib import Path
from keras.layers import LSTM
from keras.layers import Activation 
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from keras.layers import Embedding, Flatten, Conv1D, SpatialDropout1D
# from keras.layers import Embedding,Conv1D,LSTM,Input,TimeDistributed,,Flatten,Dropout
from tensorflow.keras.optimizers import Adam
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from keras.metrics import categorical_crossentropy
import glob
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import svm, datasets
from sklearn.metrics import f1_score

# %%
def get_data(c):
       # df = pd.read_csv("D:\\Projects\Federated Learning\\Datasets\\Fed Dataset Thermal (Transfer Learning Paper)\\"+self.country+".csv")
        df = pd.read_csv('../Data/Correlation Based Data/'+c+'.csv')
        y = df['Thermal sensation']
        drop_list = ['Unnamed: 0','Publication (Citation)','Data contributor','Heating strategy_building level',
                     'Year','Koppen climate classification','Climate','Building type','Database',
                     'City','Country','Outdoor monthly air temperature (¡C)','Thermal preference','Season','Cooling startegy_building level',
                     'Air movement preference','Humidity preference','Thermal comfort','PMV','Thermal sensation','label']
        drop = list(set(df.columns).intersection(drop_list))
        X = df.drop(drop, axis = 1)
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
        
        y_train=to_categorical(y_train,num_classes=5)
        y_test=to_categorical(y_test,num_classes=5)
        
        X_train = np.asarray(X_train).astype(np.float32)
        y_train = np.asarray(y_train).astype(np.float32)
        
        #for LSTM CNN model
#         X_train=np.array(X_train).reshape(X_train.shape[0],X_train.shape[1],-1)
#         X_test=np.array(X_test).reshape(X_test.shape[0],X_test.shape[1],-1)
        #For DNN Model
        #y_train = np.reshape(y_train, (len(y_train), len(y_train[0])))
        
        return X_train, X_test, y_train, y_test

# %%
labels = ['India', 'Italy', 'Pakistan', 'Philippines', 'Portugal', 'Singapore', 'Sweden', 'Thailand', 'Tunisia','UK',"Scales","Medium_US"]
path = 'countries results/'

# path = 'Synthetic Data Results/'
# labels = ['syn_data_0','syn_data_1',"syn_data_2","syn_data_3","syn_data_4", "syn_data_5","syn_data_6","syn_data_7","syn_data_8","syn_data_9"]

# %%
def build_model(X_train):
      MLP_model=Sequential()
      MLP_model.add(Dense(1024,activation='relu',input_shape = (len(list(X_train[0])),)))
#       MLP_model.add(Dense(512,activation='relu',kernel_initializer='glorot_uniform'))
#       MLP_model.add(Dense(256,activation='relu',kernel_initializer='glorot_uniform'))
#       MLP_model.add(Dense(128,activation='relu',kernel_initializer='glorot_uniform'))
#       MLP_model.add(Dense(64,activation='relu',kernel_initializer='glorot_uniform'))
#       MLP_model.add(Dense(32,activation='relu',kernel_initializer='glorot_uniform'))
#       MLP_model.add(Dense(16,activation='relu',kernel_initializer='glorot_uniform'))
#       MLP_model.add(Dense(8,activation='relu',kernel_initializer='glorot_uniform'))
      MLP_model.add(Dense(5,activation='softmax'))
      MLP_model.compile(optimizer=Adam(lr=0.001),metrics=['accuracy'],loss='categorical_crossentropy',weighted_metrics=['accuracy'])
      return MLP_model

# %%
def get_thermal_model(X_train):
        #X_train=np.array(X_train).reshape(X_train.shape[0],X_train.shape[1],-1)
        model=Sequential()
        #print(self.X_train.shape[2],"----------------")
        #model.add(Embedding(101,256,input_length=8,))
        model.add(Conv1D(filters=128,kernel_size=5,padding='same',input_shape=(X_train.shape[1],X_train.shape[2])))
        model.add(LSTM(256,return_sequences=True))
        model.add(LSTM(256,return_sequences=True))
        model.add(Flatten())
        model.add(Dense(64,activation='relu'))
        model.add(Dropout(0.1))
        model.add(Dense(16,activation='relu'))
        model.add(Dropout(0.1))
        model.add(Dense(5,activation='softmax'))
        model.compile(loss='categorical_crossentropy',optimizer=Adam(learning_rate=0.001,beta_1=0.99,beta_2=0.999),metrics=['accuracy'],weighted_metrics=['accuracy'])
        return model

# %%
def save_history_full(c,performance):
        df = pd.DataFrame(performance)
        df.to_csv(path+c+'_LSTMCNN_performance.csv', mode='w',header=True)

# %%
def my_to_catagorical(self, y_predict):
        updated_y_predict = []
        for p in y_predict:
            n = max(p)
            for i in range(0,len(p)):
               if n == p[i]:
                   p[i] = 1
               else:
                   p[i] = 0
            updated_y_predict.append(p)
        return updated_y_predict

# %%
precision_all = []
for c in labels:
    X_train, X_test, y_train, y_test = get_data(c)
    model = build_model(X_train)
    history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=100)
    #save_history_full(c,history.history)
    train_p = model.predict(X_train)
    test_p = model.predict(X_test)
    temp_pre = []
    cat_train_p = my_to_catagorical(train_p)
    report = classification_report(y_train, cat_train_p,output_dict=True)
    precision = [[c,p['precision']] for [c,p] in report.items()]
    train_classwise_precision = precision[0:5]
    train_avg_precision = precision[8]
    temp_pre.append(train_avg_precision[1])
    temp_pre.extend([train_classwise_precision[0][1],train_classwise_precision[1][1],train_classwise_precision[2][1],train_classwise_precision[3][1],train_classwise_precision[4][1]])
    cat_test_p = my_to_catagorical(test_p)
    report = classification_report(self.y_test, cat_test_p,output_dict=True)
    precision = [[c,p['precision']] for [c,p] in report.items()]
    test_classwise_precision = precision[0:5]
    test_avg_precision = precision[8]
    temp_pre.append(test_avg_precision[1])
    temp_pre.extend([test_classwise_precision[0][1],test_classwise_precision[1][1],test_classwise_precision[2][1],test_classwise_precision[3][1],test_classwise_precision[4][1]])
    precision_all.append(temp_pre)
    break
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-15365a8e7605> in <module>
#       3     X_train, X_test, y_train, y_test = get_data(c)
#       4     model = build_model(X_train)
# ----> 5     history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=100)
#       6     #save_history_full(c,history.history)
#       7     train_p = model.predict(X_train)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     821       # This is the first call of __call__, so we have to initialize.
#     822       initializers = []
# --> 823       self._initialize(args, kwds, add_initializers_to=initializers)
#     824     finally:
#     825       # At this point we know that the initialization is complete (or less
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     695     self._concrete_stateful_fn = (
# --> 696         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     697             *args, **kwds))
#     698
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853       args, kwargs = None, None
#    2854     with self._lock:
# -> 2855       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2856     return graph_function
#    2857
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3063     arg_names = base_arg_names + missing_arg_names
#    3064     graph_function = ConcreteFunction(
# -> 3065         func_graph_module.func_graph_from_py_func(
#    3066             self._name,
#    3067             self._python_function,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:806 train_function  *
#         return step_function(self, iterator)
#     C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:796 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\distribute\distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:789 run_step  **
#         outputs = model.train_step(data)
#     C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:747 train_step
#         y_pred = self(x, training=True)
#     C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:975 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs,
#     C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\keras\engine\input_spec.py:212 assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer sequential is incompatible with the layer: expected axis -1 of input shape to have value 10 but received input with shape [32, 10, 1]

# %%
for c in labels:
    X_train, X_test, y_train, y_test = get_data(c)
    model = get_thermal_model(X_train)
    history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=100)
    save_history_full(c,history.history)
# Out:
# Epoch 1/100
# 350/350 [==============================] - 9s 19ms/step - loss: 1.4279 - accuracy: 0.4297 - weighted_accuracy: 0.4297 - val_loss: 1.3875 - val_accuracy: 0.4395 - val_weighted_accuracy: 0.4395
# Epoch 2/100
# 350/350 [==============================] - 8s 22ms/step - loss: 1.3916 - accuracy: 0.4453 - weighted_accuracy: 0.4453 - val_loss: 1.3550 - val_accuracy: 0.4462 - val_weighted_accuracy: 0.4462
# Epoch 3/100
# 350/350 [==============================] - 6s 17ms/step - loss: 1.3613 - accuracy: 0.4470 - weighted_accuracy: 0.4470 - val_loss: 1.3495 - val_accuracy: 0.4497 - val_weighted_accuracy: 0.4497
# Epoch 4/100
# 350/350 [==============================] - 6s 17ms/step - loss: 1.3492 - accuracy: 0.4522 - weighted_accuracy: 0.4522 - val_loss: 1.3497 - val_accuracy: 0.4514 - val_weighted_accuracy: 0.4514
# Epoch 5/100
# 350/350 [==============================] - 6s 16ms/step - loss: 1.3362 - accuracy: 0.4613 - weighted_accuracy: 0.4613 - val_loss: 1.3255 - val_accuracy: 0.4607 - val_weighted_accuracy: 0.4607
# Epoch 6/100
# 350/350 [==============================] - 6s 16ms/step - loss: 1.3453 - accuracy: 0.4560 - weighted_accuracy: 0.4560 - val_loss: 1.3328 - val_accuracy: 0.4532 - val_weighted_accuracy: 0.4532
# Epoch 7/100
# 350/350 [==============================] - 6s 16ms/step - loss: 1.3394 - accuracy: 0.4563 - weighted_accuracy: 0.4563 - val_loss: 1.3235 - val_accuracy: 0.4578 - val_weighted_accuracy: 0.4578
# Epoch 8/100
# 350/350 [==============================] - 6s 16ms/step - loss: 1.3312 - accuracy: 0.4582 - weighted_accuracy: 0.4582 - val_loss: 1.3287 - val_accuracy: 0.4480 - val_weighted_accuracy: 0.4480
# Epoch 9/100
# 350/350 [==============================] - 8s 22ms/step - loss: 1.3218 - accuracy: 0.4613 - weighted_accuracy: 0.4613 - val_loss: 1.3190 - val_accuracy: 0.4595 - val_weighted_accuracy: 0.4595
# Epoch 10/100
# 350/350 [==============================] - 6s 17ms/step - loss: 1
- val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 70/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0879 - accuracy: 0.5584 - weighted_accuracy: 0.5584 - val_loss: 1.2984 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 71/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0756 - accuracy: 0.5685 - weighted_accuracy: 0.5685 - val_loss: 1.3225 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 72/100
# 7/7 [==============================] - 2s 313ms/step - loss: 1.0774 - accuracy: 0.5787 - weighted_accuracy: 0.5787 - val_loss: 1.3502 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 73/100
# 7/7 [==============================] - 0s 14ms/step - loss: 1.1004 - accuracy: 0.5482 - weighted_accuracy: 0.5482 - val_loss: 1.3416 - val_accuracy: 0.5647 - val_weighted_accuracy: 0.5647
# Epoch 74/100
# 7/7 [==============================] - 0s 15ms/step - loss: 1.0795 - accuracy: 0.5533 - weighted_accuracy: 0.5533 - val_loss: 1.3155 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 75/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.0522 - accuracy: 0.5635 - weighted_accuracy: 0.5635 - val_loss: 1.3066 - val_accuracy: 0.5647 - val_weighted_accuracy: 0.5647
# Epoch 76/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.0503 - accuracy: 0.5685 - weighted_accuracy: 0.5685 - val_loss: 1.3211 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 77/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0663 - accuracy: 0.5787 - weighted_accuracy: 0.5787 - val_loss: 1.3273 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 78/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.0545 - accuracy: 0.5482 - weighted_accuracy: 0.5482 - val_loss: 1.3015 - val_accuracy: 0.5765 - val_weighted_accuracy: 0.5765
# Epoch 79/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.0636 - accuracy: 0.5431 - weighted_accuracy: 0.5431 - val_loss: 1.3035 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 80/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.0721 - accuracy: 0.5736 - weighted_accuracy: 0.5736 - val_loss: 1.3056 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 81/100
# 7/7 [==============================] - 0s 16ms/step - loss: 1.0531 - accuracy: 0.5685 - weighted_accuracy: 0.5685 - val_loss: 1.3180 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 82/100
# 7/7 [==============================] - 0s 12ms/step - loss: 1.0736 - accuracy: 0.5888 - weighted_accuracy: 0.5888 - val_loss: 1.3170 - val_accuracy: 0.5647 - val_weighted_accuracy: 0.5647
# Epoch 83/100
# 7/7 [==============================] - 2s 308ms/step - loss: 1.0510 - accuracy: 0.5584 - weighted_accuracy: 0.5584 - val_loss: 1.2941 - val_accuracy: 0.5647 - val_weighted_accuracy: 0.5647
# Epoch 84/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0480 - accuracy: 0.5635 - weighted_accuracy: 0.5635 - val_loss: 1.3030 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 85/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0644 - accuracy: 0.5330 - weighted_accuracy: 0.5330 - val_loss: 1.2920 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 86/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0769 - accuracy: 0.5482 - weighted_accuracy: 0.5482 - val_loss: 1.2997 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 87/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0658 - accuracy: 0.5635 - weighted_accuracy: 0.5635 - val_loss: 1.3122 - val_accuracy: 0.5412 - val_weighted_accuracy: 0.5412
# Epoch 88/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0379 - accuracy: 0.5685 - weighted_accuracy: 0.5685 - val_loss: 1.3490 - val_accuracy: 0.5412 - val_weighted_accuracy: 0.5412
# Epoch 89/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0785 - accuracy: 0.5635 - weighted_accuracy: 0.5635 - val_loss: 1.3712 - val_accuracy: 0.5412 - val_weighted_accuracy: 0.5412
# Epoch 90/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0281 - accuracy: 0.5838 - weighted_accuracy: 0.5838 - val_loss: 1.3685 - val_accuracy: 0.4941 - val_weighted_accuracy: 0.4941
# Epoch 91/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0627 - accuracy: 0.5787 - weighted_accuracy: 0.5787 - val_loss: 1.3604 - val_accuracy: 0.5059 - val_weighted_accuracy: 0.5059
# Epoch 92/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0232 - accuracy: 0.5584 - weighted_accuracy: 0.5584 - val_loss: 1.3220 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 93/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0378 - accuracy: 0.5431 - weighted_accuracy: 0.5431 - val_loss: 1.3078 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 94/100
# 7/7 [==============================] - 0s 11ms/step - loss: 1.0615 - accuracy: 0.5838 - weighted_accuracy: 0.5838 - val_loss: 1.2957 - val_accuracy: 0.5529 - val_weighted_accuracy: 0.5529
# Epoch 95/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0675 - accuracy: 0.5736 - weighted_accuracy: 0.5736 - val_loss: 1.3150 - val_accuracy: 0.5412 - val_weighted_accuracy: 0.5412
# Epoch 96/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0730 - accuracy: 0.5533 - weighted_accuracy: 0.5533 - val_loss: 1.3441 - val_accuracy: 0.5412 - val_weighted_accuracy: 0.5412
# Epoch 97/100
# 7/7 [==============================] - 2s 312ms/step - loss: 1.0888 - accuracy: 0.5533 - weighted_accuracy: 0.5533 - val_loss: 1.3507 - val_accuracy: 0.5176 - val_weighted_accuracy: 0.5176
# Epoch 98/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0885 - accuracy: 0.5228 - weighted_accuracy: 0.5228 - val_loss: 1.3589 - val_accuracy: 0.5176 - val_weighted_accuracy: 0.5176
# Epoch 99/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0667 - accuracy: 0.5482 - weighted_accuracy: 0.5482 - val_loss: 1.3708 - val_accuracy: 0.5294 - val_weighted_accuracy: 0.5294
# Epoch 100/100
# 7/7 [==============================] - 0s 10ms/step - loss: 1.0600 - accuracy: 0.5736 - weighted_accuracy: 0.5736 - val_loss: 1.3690 - val_accuracy: 0.5412 - val_weighted_accuracy: 0.5412
# Epoch 1/100
# 92/92 [==============================] - 5s 31ms/step - loss: 1.2834 - accuracy: 0.5247 - weighted_accuracy: 0.5247 - val_loss: 1.1375 - val_accuracy: 0.5929 - val_weighted_accuracy: 0.5929
# Epoch 2/100
# 92/92 [==============================] - 1s 8ms/step - loss: 1.1520 - accuracy: 0.5607 - weighted_accuracy: 0.5607 - val_loss: 1.0481 - val_accuracy: 0.6183 - val_weighted_accuracy: 0.6183
# Epoch 3/100
# 92/92 [==============================] - 3s 28ms/step - loss: 1.1002 - accuracy: 0.5805 - weighted_accuracy: 0.5805 - val_loss: 1.0520 - val_accuracy: 0.5857 - val_weighted_accuracy: 0.5857
# Epoch 4/100
# 92/92 [==============================] - 3s 28ms/step - loss: 1.1028 - accuracy: 0.5686 - weighted_accuracy: 0.5686 - val_loss: 1.0205 - val_accuracy: 0.6294 - val_weighted_accuracy: 0.6294
# Epoch 5/100
# 92/92 [==============================] - 3s 27ms/step - loss: 1.0652 - accuracy: 0.5900 - weighted_accuracy: 0.5900 - val_loss: 1.0154 - val_accuracy: 0.6071 - val_weighted_accuracy: 0.6071
# Epoch 6/100
# 92/92 [==============================] - 1s 8ms/step - loss: 1.0413 - accuracy: 0.5914 - weighted_accuracy: 0.5914 - val_loss: 0.9847 - val_accuracy: 0.6357 - val_weighted_accuracy: 0.6357
# Epoch 7/100
# 92/92 [==============================] - 3s 28ms/step - loss: 1.0309 - accuracy: 0.5965 - weighted_accuracy: 0.5965 - val_loss: 0.9827 - val_accuracy: 0.6373 - val_weighted_accuracy: 0.6373
# Epoch 8/100
# 92/92 [==============================] - 2s 27ms/step - loss: 1.0150 - accuracy: 0.5975 - weighted_accuracy: 0.5975 - val_loss: 0.9947 - val_accuracy: 0.6190 - val_weighted_accuracy: 0.6190
# Epoch 9/100
# 92/92 [==============================] - 1s 8ms/step - loss: 1.0181 - accuracy: 0.6080 - weighted_accuracy: 0.6080 - val_loss: 1.0166 - val_accuracy: 0.6214 - val_weighted_accuracy: 0.6214
# Epoch 10/100
# 92/92 [==============================] - 3s 28ms/step - loss: 1.0020 - accuracy: 0.6084 - weighted_accuracy: 0.6084 - val_loss: 0.9660 - val_accuracy: 0.6452 - val_weighted_accuracy: 0.6452
# Epoch 11/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.9937 - accuracy: 0.6002 - weighted_accuracy: 0.6002 - val_loss: 0.9678 - val_accuracy: 0.6421 - val_weighted_accuracy: 0.6421
# Epoch 12/100
# 92/92 [==============================] - 1s 8ms/step - loss: 0.9872 - accuracy: 0.6128 - weighted_accuracy: 0.6128 - val_loss: 0.9619 - val_accuracy: 0.6468 - val_weighted_accuracy: 0.6468
# Epoch 13/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.9783 - accuracy: 0.6053 - weighted_accuracy: 0.6053 - val_loss: 0.9666 - val_accuracy: 0.6333 - val_weighted_accuracy: 0.6333
# Epoch 14/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.9624 - accuracy: 0.6182 - weighted_accuracy: 0.6182 - val_loss: 0.9430 - val_accuracy: 0.6373 - val_weighted_accuracy: 0.6373
# Epoch 15/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.9503 - accuracy: 0.6308 - weighted_accuracy: 0.6308 - val_loss: 0.9315 - val_accuracy: 0.6349 - val_weighted_accuracy: 0.6349
# Epoch 16/100
# 92/92 [==============================] - 1s 8ms/step - loss: 0.9556 - accuracy: 0.6220 - weighted_accuracy: 0.6220 - val_loss: 0.9317 - val_accuracy: 0.6349 - val_weighted_accuracy: 0.6349
# Epoch 17/100
# 92/92 [==============================] - 3s 27ms/step - loss: 0.9563 - accuracy: 0.6206 - weighted_accuracy: 0.6206 - val_loss: 0.9407 - val_accuracy: 0.6413 - val_weighted_accuracy: 0.6413
# Epoch 18/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.9639 - accuracy: 0.6097 - weighted_accuracy: 0.6097 - val_loss: 0.9558 - val_accuracy: 0.6413 - val_weighted_accuracy: 0.6413
# Epoch 19/100
# 92/92 [==============================] - 1s 8ms/step - loss: 0.9377 - accuracy: 0.6237 - weighted_accuracy: 0.6237 - val_loss: 0.9104 - val_accuracy: 0.6484 - val_weighted_accuracy: 0.6484
# Epoch 20/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.9252 - accuracy: 0.6322 - weighted_accuracy: 0.6322 - val_loss: 0.9272 - val_accuracy: 0.6437 - val_weighted_accuracy: 0.6437
# Epoch 21/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.9281 - accuracy: 0.6281 - weighted_accuracy: 0.6281 - val_loss: 0.9218 - val_accuracy: 0.6540 - val_weighted_accuracy: 0.6540
# Epoch 22/100
# 92/92 [==============================] - 2s 27ms/step - loss: 0.9285 - accuracy: 0.6247 - weighted_accuracy: 0.6247 - val_loss: 0.9025 - val_accuracy: 0.6444 - val_weighted_accuracy: 0.6444
# Epoch 23/100
# 92/92 [==============================] - 1s 8ms/step - loss: 0.9086 - accuracy: 0.6257 - weighted_accuracy: 0.6257 - val_loss: 0.8869 - val_accuracy: 0.6516 - val_weighted_accuracy: 0.6516
# Epoch 24/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.8976 - accuracy: 0.6356 - weighted_accuracy: 0.6356 - val_loss: 0.9063 - val_accuracy: 0.6563 - val_weighted_accuracy: 0.6563
# Epoch 25/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.8971 - accuracy: 0.6448 - weighted_accuracy: 0.6448 - val_loss: 0.9086 - val_accuracy: 0.6548 - val_weighted_accuracy: 0.6548
# Epoch 26/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0.8820 - accuracy: 0.6438 - weighted_accuracy: 0.6438 - val_loss: 0.9038 - val_accuracy: 0.6571 - val_weighted_accuracy: 0.6571
# Epoch 27/100
# 92/92 [==============================] - 1s 8ms/step - loss: 0.8617 - accuracy: 0.6431 - weighted_accuracy: 0.6431 - val_loss: 0.9015 - val_accuracy: 0.6556 - val_weighted_accuracy: 0.6556
# Epoch 28/100
# 92/92 [==============================] - 3s 28ms/step - loss: 0